# %% [markdown]
# # Chapter 6: Index Alignment
# ## Recipes
# * [Examining the Index object](#Examining-the-index)
# * [Producing Cartesian products](#Producing-Cartesian-products)
# * [Exploding indexes](#Exploding-Indexes)
# * [Filling values with unequal indexes](#Filling-values-with-unequal-indexes)
# * [Appending columns from different DataFrames](#Appending-columns-from-different-DataFrames)
# * [Highlighting the maximum value from each column](#Highlighting-maximum-value-from-each-column)
# * [Replicating idxmax with method chaining](#Replicating-idxmax-with-method-chaining)
# * [Finding the most common maximum](#Finding-the-most-common-maximum)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Examining the index

# %%
college = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/college.csv')
columns = college.columns
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
columns.values
# Out:
# array(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY',
#        'RELAFFIL', 'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS',
#        'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN',
#        'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF',
#        'CURROPER', 'PCTPELL', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10',
#        'GRAD_DEBT_MDN_SUPP'], dtype=object)

# %%
columns[5]
# Out:
# 'WOMENONLY'

# %%
columns[[1,8,10]]
# Out:
# Index(['CITY', 'SATMTMID', 'UGDS'], dtype='object')

# %%
columns[-7:-4]
# Out:
# Index(['PPTUG_EF', 'CURROPER', 'PCTPELL'], dtype='object')

# %%
columns.min(), columns.max(), columns.isnull().sum()
# Out:
# ('CITY', 'WOMENONLY', 0)

# %%
columns + '_A'
# Out:
# Index(['INSTNM_A', 'CITY_A', 'STABBR_A', 'HBCU_A', 'MENONLY_A', 'WOMENONLY_A',
#        'RELAFFIL_A', 'SATVRMID_A', 'SATMTMID_A', 'DISTANCEONLY_A', 'UGDS_A',
#        'UGDS_WHITE_A', 'UGDS_BLACK_A', 'UGDS_HISP_A', 'UGDS_ASIAN_A',
#        'UGDS_AIAN_A', 'UGDS_NHPI_A', 'UGDS_2MOR_A', 'UGDS_NRA_A',
#        'UGDS_UNKN_A', 'PPTUG_EF_A', 'CURROPER_A', 'PCTPELL_A', 'PCTFLOAN_A',
#        'UG25ABV_A', 'MD_EARN_WNE_P10_A', 'GRAD_DEBT_MDN_SUPP_A'],
#       dtype='object')

# %%
columns > 'G'
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True])

# %%
columns[1] = 'city'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0697dab364a3> in <module>
# ----> 1 columns[1] = 'city'
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4258
#    4259     def __setitem__(self, key, value):
# -> 4260         raise TypeError("Index does not support mutable operations")
#    4261
#    4262     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
c1 = columns[:4]
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
c2 = columns[2:5]
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY'], dtype='object')

# %%
c1.union(c2)
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR'], dtype='object')

# %%
c1 | c2
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR'], dtype='object')

# %%
c1.symmetric_difference(c2)
# Out:
# Index(['CITY', 'INSTNM', 'MENONLY'], dtype='object')

# %%
c1 ^ c2
# Out:
# Index(['CITY', 'INSTNM', 'MENONLY'], dtype='object')

# %% [markdown]
# # Producing Cartesian products

# %%
s1 = pd.Series(index=list('aaab'), data=np.arange(4))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# dtype: int32

# %%
s2 = pd.Series(index=list('cababb'), data=np.arange(6))
s2
# Out:
# c    0
# a    1
# b    2
# a    3
# b    4
# b    5
# dtype: int32

# %%
s1 + s2
# Out:
# a    1.0
# a    3.0
# a    2.0
# a    4.0
# a    3.0
# a    5.0
# b    5.0
# b    7.0
# b    8.0
# c    NaN
# dtype: float64

# %% [markdown]
# ## There's more

# %%
s1 = pd.Series(index=list('aaabb'), data=np.arange(5))
s2 = pd.Series(index=list('aaabb'), data=np.arange(5))
s1 + s2
# Out:
# a    0
# a    2
# a    4
# b    6
# b    8
# dtype: int32

# %%
s1 = pd.Series(index=list('aaabb'), data=np.arange(5))
s2 = pd.Series(index=list('bbaaa'), data=np.arange(5))
s1 + s2
# Out:
# a    2
# a    3
# a    4
# a    3
# a    4
# a    5
# a    4
# a    5
# a    6
# b    3
# b    4
# b    4
# b    5
# dtype: int32

# %% [markdown]
# # Exploding Indexes

# %%
employee = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/employee.csv', index_col='RACE')
employee.head()
# Out:
#                  UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino          0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino          1            LIBRARY ASSISTANT
# White                    2               POLICE OFFICER
# White                    3            ENGINEER/OPERATOR
# White                    4                  ELECTRICIAN
#
#                                     DEPARTMENT  BASE_SALARY EMPLOYMENT_TYPE  \
# RACE
# Hispanic/Latino    Municipal Courts Department     121862.0       Full Time
# Hispanic/Latino                        Library      26125.0       Full Time
# White            Houston Police Department-HPD      45279.0       Full Time
# White            Houston Fire Department (HFD)      63166.0       Full Time
# White              General Services Department      56347.0       Full Time
#
#                  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# RACE
# Hispanic/Latino  Female            Active  2006-06-12  2012-10-13
# Hispanic/Latino  Female            Active  2000-07-19  2010-09-18
# White              Male            Active  2015-02-03  2015-02-03
# White              Male            Active  1982-02-08  1991-05-25
# White              Male            Active  1989-06-19  1994-10-22

# %%
salary1 = employee['BASE_SALARY']
salary2 = employee['BASE_SALARY']
print(id(salary1))
print(id(salary2))
print(salary1 is salary2)
# Out:
# 263293384
# 263293384
# True

# %%
salary1 = employee['BASE_SALARY'].copy()
salary2 = employee['BASE_SALARY'].copy()
print(id(salary1))
print(id(salary2))
print(salary1 is salary2)
# Out:
# 67259080
# 263307720
# False

# %%
print(salary1.head(20))
salary1 = salary1.sort_index()
print(salary1.index)
print(salary1.head(20))
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
# American Indian or Alaskan Native    49379.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    68299.0
# American Indian or Alaskan Native    60347.0
# American Indian or Alaskan Native    81239.0
# American Indian or Alaskan Native    58855.0
# Asian/Pacific Islander               55378.0
# Asian/Pacific Islander               28169.0
# Asian/Pacific Islander               26125.0
# Asian/Pacific Islander               47650.0
# Asian/Pacific Islander               54288.0
# Asian/Pacific Islander               46010.0
# Asian/Pacific Islander               42000.0
# Asian/Pacific Islander               31034.0
# Asian/Pacific Islander               47050.0
# Name: BASE_SALARY, dtype: float64
# Index(['American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        ...
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan,
#                                        nan],
#       dtype='object', name='RACE', length=2000)
# RACE
# American Indian or Alaskan Native     78355.0
# American Indian or Alaskan Native     81239.0
# American Indian or Alaskan Native     60347.0
# American Indian or Alaskan Native     68299.0
# American Indian or Alaskan Native     26125.0
# American Indian or Alaskan Native     58855.0
# American Indian or Alaskan Native     55461.0
# American Indian or Alaskan Native         NaN
# American Indian or Alaskan Native     98536.0
# American Indian or Alaskan Native     26125.0
# American Indian or Alaskan Native     49379.0
# Asian/Pacific Islander                66614.0
# Asian/Pacific Islander                55461.0
# Asian/Pacific Islander               102019.0
# Asian/Pacific Islander                74097.0
# Asian/Pacific Islander                65402.0
# Asian/Pacific Islander                61643.0
# Asian/Pacific Islander                55461.0
# Asian/Pacific Islander                50621.0
# Asian/Pacific Islander                62432.0
# Name: BASE_SALARY, dtype: float64

# %%
salary2.sort_index().head()
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
# Name: BASE_SALARY, dtype: float64

# %%
salary_add = salary1 + salary2

# %%
salary_add.head()
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
# Name: BASE_SALARY, dtype: float64

# %%
salary_add1 = salary1 + salary1
len(salary1), len(salary2), len(salary_add), len(salary_add1)
# Out:
# (2000, 2000, 1175424, 2000)

# %% [markdown]
# ## There's more...

# %%
index_vc = salary1.index.value_counts(dropna=False)
index_vc
# Out:
# Black or African American            700
# White                                665
# Hispanic/Latino                      480
# Asian/Pacific Islander               107
# NaN                                   35
# American Indian or Alaskan Native     11
# Others                                 2
# Name: RACE, dtype: int64

# %%
index_vc.pow(2).sum()
# Out:
# 1175424

# %% [markdown]
# # Filling values with unequal indexes

# %%
baseball_14 = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/baseball14.csv', index_col='playerID')
baseball_15 = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/baseball15.csv', index_col='playerID')
baseball_16 = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/baseball16.csv', index_col='playerID')
baseball_14.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...   RBI  \
# playerID                                                         ...
# altuvjo01    2014      1    HOU   AL  158  660  85  225  47   3  ...  59.0
# cartech02    2014      1    HOU   AL  145  507  68  115  21   1  ...  88.0
# castrja01    2014      1    HOU   AL  126  465  43  103  21   2  ...  56.0
# corpoca01    2014      1    HOU   AL   55  170  22   40   6   0  ...  19.0
# dominma01    2014      1    HOU   AL  157  564  51  121  17   0  ...  57.0
#
#              SB   CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  56.0  9.0  36   53.0  7.0  5.0  1.0  5.0  20.0
# cartech02   5.0  2.0  56  182.0  6.0  5.0  0.0  4.0  12.0
# castrja01   1.0  0.0  34  151.0  1.0  9.0  1.0  3.0  11.0
# corpoca01   0.0  0.0  14   37.0  0.0  3.0  1.0  2.0   3.0
# dominma01   0.0  1.0  29  125.0  2.0  5.0  2.0  7.0  23.0
#
# [5 rows x 21 columns]

# %%
baseball_15.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...   RBI  \
# playerID                                                         ...
# altuvjo01    2015      1    HOU   AL  154  638  86  200  40   4  ...  66.0
# cartech02    2015      1    HOU   AL  129  391  50   78  17   0  ...  64.0
# castrja01    2015      1    HOU   AL  104  337  38   71  19   0  ...  31.0
# congeha01    2015      1    HOU   AL   73  201  25   46  11   0  ...  33.0
# correca01    2015      1    HOU   AL   99  387  52  108  22   1  ...  68.0
#
#              SB    CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  38.0  13.0  33   67.0  8.0  9.0  3.0  6.0  17.0
# cartech02   1.0   2.0  57  151.0  1.0  6.0  0.0  5.0   5.0
# castrja01   0.0   0.0  33  115.0  1.0  2.0  0.0  3.0   5.0
# congeha01   0.0   1.0  23   63.0  0.0  2.0  1.0  2.0   6.0
# correca01  14.0   4.0  40   78.0  2.0  1.0  0.0  4.0  10.0
#
# [5 rows x 21 columns]

# %%
baseball_16.head()
# Out:
#            yearID  stint teamID lgID    G   AB    R    H  2B  3B  ...   RBI  \
# playerID                                                          ...
# altuvjo01    2016      1    HOU   AL  161  640  108  216  42   5  ...  96.0
# bregmal01    2016      1    HOU   AL   49  201   31   53  13   3  ...  34.0
# castrja01    2016      1    HOU   AL  113  329   41   69  16   3  ...  32.0
# correca01    2016      1    HOU   AL  153  577   76  158  36   3  ...  96.0
# gattiev01    2016      1    HOU   AL  128  447   58  112  19   0  ...  72.0
#
#              SB    CS  BB     SO   IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  30.0  10.0  60   70.0  11.0  7.0  3.0  7.0  15.0
# bregmal01   2.0   0.0  15   52.0   0.0  0.0  0.0  1.0   1.0
# castrja01   2.0   1.0  45  123.0   0.0  1.0  1.0  0.0   9.0
# correca01  13.0   3.0  75  139.0   5.0  5.0  0.0  3.0  12.0
# gattiev01   2.0   1.0  43  127.0   6.0  4.0  0.0  5.0  12.0
#
# [5 rows x 21 columns]

# %%
baseball_14.index
# Out:
# Index(['altuvjo01', 'cartech02', 'castrja01', 'corpoca01', 'dominma01',
#        'fowlede01', 'gonzama01', 'grossro01', 'guzmaje01', 'hoeslj01',
#        'krausma01', 'marisja01', 'preslal01', 'singljo02', 'springe01',
#        'villajo01'],
#       dtype='object', name='playerID')

# %%
baseball_15.index
# Out:
# Index(['altuvjo01', 'cartech02', 'castrja01', 'congeha01', 'correca01',
#        'gattiev01', 'gomezca01', 'gonzama01', 'lowrije01', 'marisja01',
#        'rasmuco01', 'springe01', 'tuckepr01', 'valbulu01', 'villajo01'],
#       dtype='object', name='playerID')

# %%
baseball_16.index
# Out:
# Index(['altuvjo01', 'bregmal01', 'castrja01', 'correca01', 'gattiev01',
#        'gomezca01', 'gonzama01', 'gourryu01', 'kempto01', 'marisja01',
#        'rasmuco01', 'reedaj01', 'springe01', 'tuckepr01', 'valbulu01',
#        'whitety01'],
#       dtype='object', name='playerID')

# %%
baseball_14.index.difference(baseball_15.index)
# Out:
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01', 'guzmaje01',
#        'hoeslj01', 'krausma01', 'preslal01', 'singljo02'],
#       dtype='object', name='playerID')

# %%
baseball_14.index.difference(baseball_15.index)
# Out:
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01', 'guzmaje01',
#        'hoeslj01', 'krausma01', 'preslal01', 'singljo02'],
#       dtype='object', name='playerID')

# %%
hits_14 = baseball_14['H']
hits_15 = baseball_15['H']
hits_16 = baseball_16['H']
hits_14.head(20)
# Out:
# playerID
# altuvjo01    225
# cartech02    115
# castrja01    103
# corpoca01     40
# dominma01    121
# fowlede01    120
# gonzama01     79
# grossro01     84
# guzmaje01     31
# hoeslj01      21
# krausma01     36
# marisja01     47
# preslal01     62
# singljo02     52
# springe01     68
# villajo01     55
# Name: H, dtype: int64

# %%
hits_15.head(20)
# Out:
# playerID
# altuvjo01    200
# cartech02     78
# castrja01     71
# congeha01     46
# correca01    108
# gattiev01    139
# gomezca01     36
# gonzama01     96
# lowrije01     51
# marisja01     80
# rasmuco01    103
# springe01    107
# tuckepr01     73
# valbulu01     97
# villajo01     33
# Name: H, dtype: int64

# %%
hits_16.head(20)
# Out:
# playerID
# altuvjo01    216
# bregmal01     53
# castrja01     69
# correca01    158
# gattiev01    112
# gomezca01     62
# gonzama01    123
# gourryu01     34
# kempto01      26
# marisja01     60
# rasmuco01     76
# reedaj01      20
# springe01    168
# tuckepr01     22
# valbulu01     76
# whitety01     54
# Name: H, dtype: int64

# %%
(hits_14 + hits_15).head(20)
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01      NaN
# corpoca01      NaN
# correca01      NaN
# dominma01      NaN
# fowlede01      NaN
# gattiev01      NaN
# gomezca01      NaN
# gonzama01    175.0
# grossro01      NaN
# guzmaje01      NaN
# hoeslj01       NaN
# krausma01      NaN
# lowrije01      NaN
# marisja01    127.0
# preslal01      NaN
# rasmuco01      NaN
# singljo02      NaN
# Name: H, dtype: float64

# %%
hits_14.add(hits_15, fill_value=0).head(20)
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01     46.0
# corpoca01     40.0
# correca01    108.0
# dominma01    121.0
# fowlede01    120.0
# gattiev01    139.0
# gomezca01     36.0
# gonzama01    175.0
# grossro01     84.0
# guzmaje01     31.0
# hoeslj01      21.0
# krausma01     36.0
# lowrije01     51.0
# marisja01    127.0
# preslal01     62.0
# rasmuco01    103.0
# singljo02     52.0
# Name: H, dtype: float64

# %%
hits_total = hits_14.add(hits_15, fill_value=0).add(hits_16, fill_value=0)
hits_total.head(20)
# Out:
# playerID
# altuvjo01    641.0
# bregmal01     53.0
# cartech02    193.0
# castrja01    243.0
# congeha01     46.0
# corpoca01     40.0
# correca01    266.0
# dominma01    121.0
# fowlede01    120.0
# gattiev01    251.0
# gomezca01     98.0
# gonzama01    298.0
# gourryu01     34.0
# grossro01     84.0
# guzmaje01     31.0
# hoeslj01      21.0
# kempto01      26.0
# krausma01     36.0
# lowrije01     51.0
# marisja01    187.0
# Name: H, dtype: float64

# %%
hits_total.hasnans
# Out:
# False

# %% [markdown]
# ## How it works...

# %%
s = pd.Series(index=['a', 'b', 'c', 'd'], data=[np.nan, 3, np.nan, 1])
s
# Out:
# a    NaN
# b    3.0
# c    NaN
# d    1.0
# dtype: float64

# %%
s1 = pd.Series(index=['a', 'b', 'c'], data=[np.nan, 6, 10])
s1
# Out:
# a     NaN
# b     6.0
# c    10.0
# dtype: float64

# %%
s.add(s1, fill_value=5)
# Out:
# a     NaN
# b     9.0
# c    15.0
# d     6.0
# dtype: float64

# %%
s1.add(s, fill_value=5)
# Out:
# a     NaN
# b     9.0
# c    15.0
# d     6.0
# dtype: float64

# %% [markdown]
# ## There's more

# %%
df_14 = baseball_14[['G','AB', 'R', 'H']]
df_14.head()
# Out:
#              G   AB   R    H
# playerID
# altuvjo01  158  660  85  225
# cartech02  145  507  68  115
# castrja01  126  465  43  103
# corpoca01   55  170  22   40
# dominma01  157  564  51  121

# %%
df_15 = baseball_15[['AB', 'R', 'H', 'HR']]
df_15.head()
# Out:
#             AB   R    H  HR
# playerID
# altuvjo01  638  86  200  15
# cartech02  391  50   78  24
# castrja01  337  38   71  11
# congeha01  201  25   46  11
# correca01  387  52  108  22

# %%
(df_14 + df_15).head(10).style.highlight_null('yellow')
# Out:
# <style  type="text/css" >
#     #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col4 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row4_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row4_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row4_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row4_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row4_col4 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row5_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row5_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row5_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row5_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row5_col4 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row6_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row6_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row6_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row6_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row6_col4 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row7_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row7_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row7_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row7_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row7_col4 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row8_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row8_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row8_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row8_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row8_col4 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row9_col0 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row9_col1 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row9_col2 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row9_col3 {
#             background-color:  yellow;
#         }    #T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AB</th>        <th class="col_heading level0 col1" >G</th>        <th class="col_heading level0 col2" >H</th>        <th class="col_heading level0 col3" >HR</th>        <th class="col_heading level0 col4" >R</th>    </tr>    <tr>        <th class="index_name level0" >playerID</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2level0_row0" class="row_heading level0 row0" >altuvjo01</th>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col0" class="data row0 col0" >1298</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col2" class="data row0 col2" >425</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row0_col4" class="data row0 col4" >171</td>
#             </tr>
#             <tr>
#                         <th id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2level0_row1" class="row_heading level0 row1" >cartech02</th>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col0" class="data row1 col0" >898</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col2" class="data row1 col2" >193</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row1_col4" class="data row1 col4" >118</td>
#             </tr>
#             <tr>
#                         <th id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2level0_row2" class="row_heading level0 row2" >castrja01</th>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col0" class="data row2 col0" >802</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col2" class="data row2 col2" >174</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row2_col4" class="data row2 col4" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2level0_row3" class="row_heading level0 row3" >congeha01</th>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2row3_col4" class="data row3 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_5155cf0c_18eb_11ea_a44c_8091d7a966d2level0_row4" class="row_heading level0 row4" >corpoca01</th>
#                         <td id

# %%
df_14.add(df_15, fill_value=0).head(10).style.highlight_null('yellow')
# Out:
# <style  type="text/css" >
#     #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row3_col1 {
#             background-color:  yellow;
#         }    #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row4_col3 {
#             background-color:  yellow;
#         }    #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row5_col1 {
#             background-color:  yellow;
#         }    #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row6_col3 {
#             background-color:  yellow;
#         }    #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row7_col3 {
#             background-color:  yellow;
#         }    #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row8_col1 {
#             background-color:  yellow;
#         }    #T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row9_col1 {
#             background-color:  yellow;
#         }</style><table id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AB</th>        <th class="col_heading level0 col1" >G</th>        <th class="col_heading level0 col2" >H</th>        <th class="col_heading level0 col3" >HR</th>        <th class="col_heading level0 col4" >R</th>    </tr>    <tr>        <th class="index_name level0" >playerID</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row0" class="row_heading level0 row0" >altuvjo01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row0_col0" class="data row0 col0" >1298</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row0_col1" class="data row0 col1" >158</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row0_col2" class="data row0 col2" >425</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row0_col3" class="data row0 col3" >15</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row0_col4" class="data row0 col4" >171</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row1" class="row_heading level0 row1" >cartech02</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row1_col0" class="data row1 col0" >898</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row1_col1" class="data row1 col1" >145</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row1_col2" class="data row1 col2" >193</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row1_col3" class="data row1 col3" >24</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row1_col4" class="data row1 col4" >118</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row2" class="row_heading level0 row2" >castrja01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row2_col0" class="data row2 col0" >802</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row2_col1" class="data row2 col1" >126</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row2_col2" class="data row2 col2" >174</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row2_col3" class="data row2 col3" >11</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row2_col4" class="data row2 col4" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row3" class="row_heading level0 row3" >congeha01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row3_col0" class="data row3 col0" >201</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row3_col2" class="data row3 col2" >46</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row3_col3" class="data row3 col3" >11</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row3_col4" class="data row3 col4" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row4" class="row_heading level0 row4" >corpoca01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row4_col0" class="data row4 col0" >170</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row4_col1" class="data row4 col1" >55</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row4_col2" class="data row4 col2" >40</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row4_col4" class="data row4 col4" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row5" class="row_heading level0 row5" >correca01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row5_col0" class="data row5 col0" >387</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row5_col2" class="data row5 col2" >108</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row5_col3" class="data row5 col3" >22</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row5_col4" class="data row5 col4" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row6" class="row_heading level0 row6" >dominma01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row6_col0" class="data row6 col0" >564</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row6_col1" class="data row6 col1" >157</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row6_col2" class="data row6 col2" >121</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row6_col4" class="data row6 col4" >51</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row7" class="row_heading level0 row7" >fowlede01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row7_col0" class="data row7 col0" >434</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row7_col1" class="data row7 col1" >116</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row7_col2" class="data row7 col2" >120</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row7_col4" class="data row7 col4" >61</td>
#             </tr>
#             <tr>
#                         <th id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2level0_row8" class="row_heading level0 row8" >gattiev01</th>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row8_col0" class="data row8 col0" >566</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row8_col1" class="data row8 col1" >nan</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row8_col2" class="data row8 col2" >139</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row8_col3" class="data row8 col3" >27</td>
#                         <td id="T_89e8c0fe_18eb_11ea_a31a_8091d7a966d2row8_col4" class="data row8 col4" >66</td>
#             </tr>
#             <tr

# %% [markdown]
# # Appending columns from different DataFrames

# %%
employee = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/employee.csv')
dept_sal = employee[['DEPARTMENT', 'BASE_SALARY']]
dept_sal
# Out:
#                          DEPARTMENT  BASE_SALARY
# 0       Municipal Courts Department     121862.0
# 1                           Library      26125.0
# 2     Houston Police Department-HPD      45279.0
# 3     Houston Fire Department (HFD)      63166.0
# 4       General Services Department      56347.0
# ...                             ...          ...
# 1995  Houston Police Department-HPD      43443.0
# 1996  Houston Fire Department (HFD)      66523.0
# 1997  Houston Police Department-HPD      43443.0
# 1998  Houston Police Department-HPD      55461.0
# 1999  Houston Fire Department (HFD)      51194.0
#
# [2000 rows x 2 columns]

# %%
employee.head(20)
# Out:
#     UNIQUE_ID                            POSITION_TITLE  \
# 0           0               ASSISTANT DIRECTOR (EX LVL)
# 1           1                         LIBRARY ASSISTANT
# 2           2                            POLICE OFFICER
# 3           3                         ENGINEER/OPERATOR
# 4           4                               ELECTRICIAN
# 5           5                     SENIOR POLICE OFFICER
# 6           6                                  ENGINEER
# 7           7                                 CARPENTER
# 8           8  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# 9           9            AIRPORT OPERATIONS COORDINATOR
# 10         10                              FIRE FIGHTER
# 11         11                        CHIEF PHYSICIAN,MD
# 12         12         CUSTOMER SERVICE REPRESENTATIVE I
# 13         13     PUBLIC HEALTH INVESTIGATOR SUPERVISOR
# 14         14                           POLICE SERGEANT
# 15         15                     SENIOR POLICE OFFICER
# 16         16                     SENIOR POLICE OFFICER
# 17         17                           POLICE SERGEANT
# 18         18                  MAINTENANCE MECHANIC III
# 19         19                     SENIOR POLICE OFFICER
#
#                         DEPARTMENT  BASE_SALARY                       RACE  \
# 0      Municipal Courts Department     121862.0            Hispanic/Latino
# 1                          Library      26125.0            Hispanic/Latino
# 2    Houston Police Department-HPD      45279.0                      White
# 3    Houston Fire Department (HFD)      63166.0                      White
# 4      General Services Department      56347.0                      White
# 5    Houston Police Department-HPD      66614.0  Black or African American
# 6   Public Works & Engineering-PWE      71680.0     Asian/Pacific Islander
# 7     Houston Airport System (HAS)      42390.0                      White
# 8   Public Works & Engineering-PWE     107962.0                      White
# 9     Houston Airport System (HAS)      44616.0                        NaN
# 10   Houston Fire Department (HFD)      52644.0            Hispanic/Latino
# 11         Health & Human Services     180416.0  Black or African American
# 12  Public Works & Engineering-PWE      30347.0  Black or African American
# 13         Health & Human Services      55269.0  Black or African American
# 14   Houston Police Department-HPD      77076.0  Black or African American
# 15   Houston Police Department-HPD          NaN  Black or African American
# 16   Houston Police Department-HPD          NaN            Hispanic/Latino
# 17   Houston Police Department-HPD      81239.0                      White
# 18     General Services Department      40581.0            Hispanic/Latino
# 19   Houston Police Department-HPD      66614.0                      White
#
#    EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# 0        Full Time  Female            Active  2006-06-12  2012-10-13
# 1        Full Time  Female            Active  2000-07-19  2010-09-18
# 2        Full Time    Male            Active  2015-02-03  2015-02-03
# 3        Full Time    Male            Active  1982-02-08  1991-05-25
# 4        Full Time    Male            Active  1989-06-19  1994-10-22
# 5        Full Time    Male            Active  1984-11-26  2005-03-26
# 6        Full Time    Male            Active  2012-03-26  2012-03-26
# 7        Full Time    Male            Active  2013-11-04  2013-11-04
# 8        Full Time    Male            Active  1993-11-15  2013-01-05
# 9        Full Time    Male            Active  2016-03-14  2016-03-14
# 10       Full Time    Male            Active  2007-05-21  2008-11-15
# 11       Full Time    Male            Active  1987-05-22  1999-08-28
# 12       Full Time    Male            Active  2015-11-16  2015-11-16
# 13       Full Time    Male            Active  1999-10-20  2001-05-19
# 14       Full Time    Male            Active  2001-06-04  2015-05-25
# 15       Full Time    Male            Active  1995-01-30  2015-02-14
# 16       Full Time    Male            Active  1981-02-23  2002-01-05
# 17       Full Time    Male            Active  1995-06-19  2007-03-03
# 18       Full Time    Male            Active  2008-12-29  2008-12-29
# 19       Full Time    Male            Active  1992-02-17  2007-07-28

# %%
dept_sal = dept_sal.sort_values(['DEPARTMENT', 'BASE_SALARY'],
                                ascending=[True, False])

# %%
dept_sal
# Out:
#                       DEPARTMENT  BASE_SALARY
# 1494  Admn. & Regulatory Affairs     140416.0
# 237   Admn. & Regulatory Affairs     130416.0
# 1679  Admn. & Regulatory Affairs     103776.0
# 988   Admn. & Regulatory Affairs      72741.0
# 693   Admn. & Regulatory Affairs      66825.0
# ...                          ...          ...
# 1140      Solid Waste Management      30410.0
# 1243      Solid Waste Management      30410.0
# 387       Solid Waste Management      28829.0
# 57        Solid Waste Management      27622.0
# 536       Solid Waste Management      26499.0
#
# [2000 rows x 2 columns]

# %%
max_dept_sal = dept_sal.drop_duplicates(subset='DEPARTMENT')
max_dept_sal.head()
# Out:
#                         DEPARTMENT  BASE_SALARY
# 1494    Admn. & Regulatory Affairs     140416.0
# 149       City Controller's Office      64251.0
# 236                   City Council     100000.0
# 647   Convention and Entertainment      38397.0
# 1500   Dept of Neighborhoods (DON)      89221.0

# %%
max_dept_sal = max_dept_sal.set_index('DEPARTMENT')
employee = employee.set_index('DEPARTMENT')
employee.head(20)
# Out:
#                                 UNIQUE_ID  \
# DEPARTMENT
# Municipal Courts Department             0
# Library                                 1
# Houston Police Department-HPD           2
# Houston Fire Department (HFD)           3
# General Services Department             4
# Houston Police Department-HPD           5
# Public Works & Engineering-PWE          6
# Houston Airport System (HAS)            7
# Public Works & Engineering-PWE          8
# Houston Airport System (HAS)            9
# Houston Fire Department (HFD)          10
# Health & Human Services                11
# Public Works & Engineering-PWE         12
# Health & Human Services                13
# Houston Police Department-HPD          14
# Houston Police Department-HPD          15
# Houston Police Department-HPD          16
# Houston Police Department-HPD          17
# General Services Department            18
# Houston Police Department-HPD          19
#
#                                                           POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department                  ASSISTANT DIRECTOR (EX LVL)
# Library                                                LIBRARY ASSISTANT
# Houston Police Department-HPD                             POLICE OFFICER
# Houston Fire Department (HFD)                          ENGINEER/OPERATOR
# General Services Department                                  ELECTRICIAN
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
# Public Works & Engineering-PWE                                  ENGINEER
# Houston Airport System (HAS)                                   CARPENTER
# Public Works & Engineering-PWE  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# Houston Airport System (HAS)              AIRPORT OPERATIONS COORDINATOR
# Houston Fire Department (HFD)                               FIRE FIGHTER
# Health & Human Services                               CHIEF PHYSICIAN,MD
# Public Works & Engineering-PWE         CUSTOMER SERVICE REPRESENTATIVE I
# Health & Human Services            PUBLIC HEALTH INVESTIGATOR SUPERVISOR
# Houston Police Department-HPD                            POLICE SERGEANT
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
# Houston Police Department-HPD                            POLICE SERGEANT
# General Services Department                     MAINTENANCE MECHANIC III
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
#
#                                 BASE_SALARY                       RACE  \
# DEPARTMENT
# Municipal Courts Department        121862.0            Hispanic/Latino
# Library                             26125.0            Hispanic/Latino
# Houston Police Department-HPD       45279.0                      White
# Houston Fire Department (HFD)       63166.0                      White
# General Services Department         56347.0                      White
# Houston Police Department-HPD       66614.0  Black or African American
# Public Works & Engineering-PWE      71680.0     Asian/Pacific Islander
# Houston Airport System (HAS)        42390.0                      White
# Public Works & Engineering-PWE     107962.0                      White
# Houston Airport System (HAS)        44616.0                        NaN
# Houston Fire Department (HFD)       52644.0            Hispanic/Latino
# Health & Human Services            180416.0  Black or African American
# Public Works & Engineering-PWE      30347.0  Black or African American
# Health & Human Services             55269.0  Black or African American
# Houston Police Department-HPD       77076.0  Black or African American
# Houston Police Department-HPD           NaN  Black or African American
# Houston Police Department-HPD           NaN            Hispanic/Latino
# Houston Police Department-HPD       81239.0                      White
# General Services Department         40581.0            Hispanic/Latino
# Houston Police Department-HPD       66614.0                      White
#
#                                EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# DEPARTMENT
# Municipal Courts Department          Full Time  Female            Active
# Library                              Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Fire Department (HFD)        Full Time    Male            Active
# General Services Department          Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time    Male            Active
# Houston Airport System (HAS)         Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time    Male            Active
# Houston Airport System (HAS)         Full Time    Male            Active
# Houston Fire Department (HFD)        Full Time    Male            Active
# Health & Human Services              Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time    Male            Active
# Health & Human Services              Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# General Services Department          Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
#
#                                  HIRE_DATE    JOB_DATE
# DEPARTMENT
# Municipal Courts Department     2006-06-12  2012-10-13
# Library                         2000-07-19  2010-09-18
# Houston Police Department-HPD   2015-02-03  2015-02-03
# Houston Fire Department (HFD)   1982-02-08  1991-05-25
# General Services Department     1989-06-19  1994-10-22
# Houston Police Department-HPD   1984-11-26  2005-03-26
# Public Works & Engineering-PWE  2012-03-26  2012-03-26
# Houston Airport System (HAS)    2013-11-04  2013-11-04
# Public Works & Engineering-PWE  1993-11-15  2013-01-05
# Houston Airport System (HAS)    2016-03-14  2016-03-14
# Houston Fire Department (HFD)   2007-05-21  2008-11-15
# Health & Human Services         1987-05-22  1999-08-28
# Public Works & Engineering-PWE  2015-11-16  2015-11-16
# Health & Human Services         1999-10-20  2001-05-19
# Houston Police Department-HPD   2001-06-04  2015-05-25
# Houston Police Department-HPD   1995-01-30  2015-02-14
# Houston Police Department-HPD   1981-02-23  2002-01-05
# Houston Police Department-HPD   1995-06-19  2007-03-03
# General Services Department     2008-12-29  2008-12-29
# Houston Police Department-HPD   1992-02-17  2007-07-28

# %%
max_dept_sal.head()
# Out:
#                               BASE_SALARY
# DEPARTMENT
# Admn. & Regulatory Affairs       140416.0
# City Controller's Office          64251.0
# City Council                     100000.0
# Convention and Entertainment      38397.0
# Dept of Neighborhoods (DON)       89221.0

# %%
employee['MAX_DEPT_SALARY'] = max_dept_sal['BASE_SALARY']
employee.head(20)
# Out:
#                                 UNIQUE_ID  \
# DEPARTMENT
# Municipal Courts Department             0
# Library                                 1
# Houston Police Department-HPD           2
# Houston Fire Department (HFD)           3
# General Services Department             4
# Houston Police Department-HPD           5
# Public Works & Engineering-PWE          6
# Houston Airport System (HAS)            7
# Public Works & Engineering-PWE          8
# Houston Airport System (HAS)            9
# Houston Fire Department (HFD)          10
# Health & Human Services                11
# Public Works & Engineering-PWE         12
# Health & Human Services                13
# Houston Police Department-HPD          14
# Houston Police Department-HPD          15
# Houston Police Department-HPD          16
# Houston Police Department-HPD          17
# General Services Department            18
# Houston Police Department-HPD          19
#
#                                                           POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department                  ASSISTANT DIRECTOR (EX LVL)
# Library                                                LIBRARY ASSISTANT
# Houston Police Department-HPD                             POLICE OFFICER
# Houston Fire Department (HFD)                          ENGINEER/OPERATOR
# General Services Department                                  ELECTRICIAN
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
# Public Works & Engineering-PWE                                  ENGINEER
# Houston Airport System (HAS)                                   CARPENTER
# Public Works & Engineering-PWE  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# Houston Airport System (HAS)              AIRPORT OPERATIONS COORDINATOR
# Houston Fire Department (HFD)                               FIRE FIGHTER
# Health & Human Services                               CHIEF PHYSICIAN,MD
# Public Works & Engineering-PWE         CUSTOMER SERVICE REPRESENTATIVE I
# Health & Human Services            PUBLIC HEALTH INVESTIGATOR SUPERVISOR
# Houston Police Department-HPD                            POLICE SERGEANT
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
# Houston Police Department-HPD                            POLICE SERGEANT
# General Services Department                     MAINTENANCE MECHANIC III
# Houston Police Department-HPD                      SENIOR POLICE OFFICER
#
#                                 BASE_SALARY                       RACE  \
# DEPARTMENT
# Municipal Courts Department        121862.0            Hispanic/Latino
# Library                             26125.0            Hispanic/Latino
# Houston Police Department-HPD       45279.0                      White
# Houston Fire Department (HFD)       63166.0                      White
# General Services Department         56347.0                      White
# Houston Police Department-HPD       66614.0  Black or African American
# Public Works & Engineering-PWE      71680.0     Asian/Pacific Islander
# Houston Airport System (HAS)        42390.0                      White
# Public Works & Engineering-PWE     107962.0                      White
# Houston Airport System (HAS)        44616.0                        NaN
# Houston Fire Department (HFD)       52644.0            Hispanic/Latino
# Health & Human Services            180416.0  Black or African American
# Public Works & Engineering-PWE      30347.0  Black or African American
# Health & Human Services             55269.0  Black or African American
# Houston Police Department-HPD       77076.0  Black or African American
# Houston Police Department-HPD           NaN  Black or African American
# Houston Police Department-HPD           NaN            Hispanic/Latino
# Houston Police Department-HPD       81239.0                      White
# General Services Department         40581.0            Hispanic/Latino
# Houston Police Department-HPD       66614.0                      White
#
#                                EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# DEPARTMENT
# Municipal Courts Department          Full Time  Female            Active
# Library                              Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Fire Department (HFD)        Full Time    Male            Active
# General Services Department          Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time    Male            Active
# Houston Airport System (HAS)         Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time    Male            Active
# Houston Airport System (HAS)         Full Time    Male            Active
# Houston Fire Department (HFD)        Full Time    Male            Active
# Health & Human Services              Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time    Male            Active
# Health & Human Services              Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# General Services Department          Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
#
#                                  HIRE_DATE    JOB_DATE  MAX_DEPT_SALARY
# DEPARTMENT
# Municipal Courts Department     2006-06-12  2012-10-13         121862.0
# Library                         2000-07-19  2010-09-18         107763.0
# Houston Police Department-HPD   2015-02-03  2015-02-03         199596.0
# Houston Fire Department (HFD)   1982-02-08  1991-05-25         210588.0
# General Services Department     1989-06-19  1994-10-22          89194.0
# Houston Police Department-HPD   1984-11-26  2005-03-26         199596.0
# Public Works & Engineering-PWE  2012-03-26  2012-03-26         178331.0
# Houston Airport System (HAS)    2013-11-04  2013-11-04         186192.0
# Public Works & Engineering-PWE  1993-11-15  2013-01-05         178331.0
# Houston Airport System (HAS)    2016-03-14  2016-03-14         186192.0
# Houston Fire Department (HFD)   2007-05-21  2008-11-15         210588.0
# Health & Human Services         1987-05-22  1999-08-28         180416.0
# Public Works & Engineering-PWE  2015-11-16  2015-11-16         178331.0
# Health & Human Services         1999-10-20  2001-05-19         180416.0
# Houston Police Department-HPD   2001-06-04  2015-05-25         199596.0
# Houston Police Department-HPD   1995-01-30  2015-02-14         199596.0
# Houston Police Department-HPD   1981-02-23  2002-01-05         199596.0
# Houston Police Department-HPD   1995-06-19  2007-03-03         199596.0
# General Services Department     2008-12-29  2008-12-29          89194.0
# Houston Police Department-HPD   1992-02-17  2007-07-28         199596.0

# %%
employee[['UNIQUE_ID','MAX_DEPT_SALARY']]
# Out:
#                                UNIQUE_ID  MAX_DEPT_SALARY
# DEPARTMENT
# Municipal Courts Department            0         121862.0
# Library                                1         107763.0
# Houston Police Department-HPD          2         199596.0
# Houston Fire Department (HFD)          3         210588.0
# General Services Department            4          89194.0
# ...                                  ...              ...
# Houston Police Department-HPD       1995         199596.0
# Houston Fire Department (HFD)       1996         210588.0
# Houston Police Department-HPD       1997         199596.0
# Houston Police Department-HPD       1998         199596.0
# Houston Fire Department (HFD)       1999         210588.0
#
# [2000 rows x 2 columns]

# %%
pd.options.display.max_columns = 6

# %%
employee.head()
# Out:
#                                UNIQUE_ID               POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department            0  ASSISTANT DIRECTOR (EX LVL)
# Library                                1            LIBRARY ASSISTANT
# Houston Police Department-HPD          2               POLICE OFFICER
# Houston Fire Department (HFD)          3            ENGINEER/OPERATOR
# General Services Department            4                  ELECTRICIAN
#
#                                BASE_SALARY  ...   HIRE_DATE    JOB_DATE  \
# DEPARTMENT                                  ...
# Municipal Courts Department       121862.0  ...  2006-06-12  2012-10-13
# Library                            26125.0  ...  2000-07-19  2010-09-18
# Houston Police Department-HPD      45279.0  ...  2015-02-03  2015-02-03
# Houston Fire Department (HFD)      63166.0  ...  1982-02-08  1991-05-25
# General Services Department        56347.0  ...  1989-06-19  1994-10-22
#
#                               MAX_DEPT_SALARY
# DEPARTMENT
# Municipal Courts Department          121862.0
# Library                              107763.0
# Houston Police Department-HPD        199596.0
# Houston Fire Department (HFD)        210588.0
# General Services Department           89194.0
#
# [5 rows x 10 columns]

# %%
employee.query('BASE_SALARY > MAX_DEPT_SALARY')
# Out:
# Empty DataFrame
# Columns: [UNIQUE_ID, POSITION_TITLE, BASE_SALARY, RACE, EMPLOYMENT_TYPE, GENDER, EMPLOYMENT_STATUS, HIRE_DATE, JOB_DATE, MAX_DEPT_SALARY]
# Index: []
#
# [0 rows x 10 columns]

# %% [markdown]
# ## How it works...

# %%
np.random.seed(1234)
random_salary = dept_sal.sample(n=10).set_index('DEPARTMENT')
random_salary
# Out:
#                                 BASE_SALARY
# DEPARTMENT
# Public Works & Engineering-PWE      50586.0
# Houston Police Department-HPD       66614.0
# Houston Police Department-HPD       66614.0
# Housing and Community Devp.         78853.0
# Houston Police Department-HPD       66614.0
# Parks & Recreation                      NaN
# Public Works & Engineering-PWE      37211.0
# Public Works & Engineering-PWE      54683.0
# Human Resources Dept.               58474.0
# Health & Human Services             47050.0

# %%
employee['RANDOM_SALARY'] = random_salary['BASE_SALARY']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-2c3f44188e8c> in <module>
# ----> 1 employee['RANDOM_SALARY'] = random_salary['BASE_SALARY']
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3562
#    3563         self._ensure_valid_index(value)
# -> 3564         value = self._sanitize_column(key, value)
#    3565         NDFrame._set_item(self, key, value)
#    3566
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3724
#    3725         if isinstance(value, Series):
# -> 3726             value = reindexer(value)
#    3727
#    3728         elif isinstance(value, DataFrame):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3715                     # duplicate axis
#    3716                     if not value.index.is_unique:
# -> 3717                         raise e
#    3718
#    3719                     # other
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3710                 # GH 4107
#    3711                 try:
# -> 3712                     value = value.reindex(self.index)._values
#    3713                 except Exception as e:
#    3714
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4219     @Appender(generic.NDFrame.reindex.__doc__)
#    4220     def reindex(self, index=None, **kwargs):
# -> 4221         return super().reindex(index=index, **kwargs)
#    4222
#    4223     def drop(
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4533                 fill_value=fill_value,
#    4534                 copy=copy,
# -> 4535                 allow_dups=False,
#    4536             )
#    4537
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3360         # trying to reindex on an axis with duplicates
#    3361         if not self.is_unique and len(indexer):
# -> 3362             raise ValueError("cannot reindex from a duplicate axis")
#    3363
#    3364     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %% [markdown]
# ## There's more...

# %%
employee['MAX_SALARY2'] = max_dept_sal['BASE_SALARY'].head(3)

# %%
employee.MAX_SALARY2.value_counts()
# Out:
# 140416.0    29
# 100000.0    11
# 64251.0      5
# Name: MAX_SALARY2, dtype: int64

# %%
employee.MAX_SALARY2.isnull().mean()
# Out:
# 0.9775

# %% [markdown]
# # Highlighting maximum value from each column

# %%
pd.options.display.max_rows = 8

# %%
college = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/college.csv', index_col='INSTNM')
college.dtypes
# Out:
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %%
college.shape
# Out:
# (7535, 26)

# %%
college.head(5)
# Out:
#                                            CITY STABBR  HBCU  ...  UG25ABV  \
# INSTNM                                                        ...
# Alabama A & M University                 Normal     AL   1.0  ...   0.1049
# University of Alabama at Birmingham  Birmingham     AL   0.0  ...   0.2422
# Amridge University                   Montgomery     AL   0.0  ...   0.8540
# University of Alabama in Huntsville  Huntsville     AL   0.0  ...   0.2640
# Alabama State University             Montgomery     AL   1.0  ...   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                       30300               33888
# University of Alabama at Birmingham            39700             21941.5
# Amridge University                             40100               23370
# University of Alabama in Huntsville            45500               24097
# Alabama State University                       26600             33118.5
#
# [5 rows x 26 columns]

# %%
college.MD_EARN_WNE_P10.iloc[0]
# Out:
# '30300'

# %%
college.GRAD_DEBT_MDN_SUPP.iloc[0]
# Out:
# '33888'

# %%
college.MD_EARN_WNE_P10.sort_values(ascending=False).head()
# Out:
# INSTNM
# Sharon Regional Health System School of Nursing    PrivacySuppressed
# Northcoast Medical Training Academy                PrivacySuppressed
# Success Schools                                    PrivacySuppressed
# Louisiana Culinary Institute                       PrivacySuppressed
# Bais Medrash Toras Chesed                          PrivacySuppressed
# Name: MD_EARN_WNE_P10, dtype: object

# %%
cols = ['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']
for col in cols:
    college[col] = pd.to_numeric(college[col], errors='coerce')

college.dtypes.loc[cols]
# Out:
# MD_EARN_WNE_P10       float64
# GRAD_DEBT_MDN_SUPP    float64
# dtype: object

# %%
college_n = college.select_dtypes(include=[np.number])
college_n.head() # only numeric columns
# Out:
#                                      HBCU  MENONLY  WOMENONLY  ...  UG25ABV  \
# INSTNM                                                         ...
# Alabama A & M University              1.0      0.0        0.0  ...   0.1049
# University of Alabama at Birmingham   0.0      0.0        0.0  ...   0.2422
# Amridge University                    0.0      0.0        0.0  ...   0.8540
# University of Alabama in Huntsville   0.0      0.0        0.0  ...   0.2640
# Alabama State University              1.0      0.0        0.0  ...   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 24 columns]

# %%
criteria = college_n.nunique() == 2
criteria.head()
# Out:
# HBCU          True
# MENONLY       True
# WOMENONLY     True
# RELAFFIL      True
# SATVRMID     False
# dtype: bool

# %%
college_n.nunique()
# Out:
# HBCU                     2
# MENONLY                  2
# WOMENONLY                2
# RELAFFIL                 2
# SATVRMID               163
# SATMTMID               167
# DISTANCEONLY             2
# UGDS                  2932
# UGDS_WHITE            4397
# UGDS_BLACK            3242
# UGDS_HISP             2809
# UGDS_ASIAN            1254
# UGDS_AIAN              601
# UGDS_NHPI              363
# UGDS_2MOR              957
# UGDS_NRA               920
# UGDS_UNKN             1517
# PPTUG_EF              3420
# CURROPER                 2
# PCTPELL               4422
# PCTFLOAN              4155
# UG25ABV               4285
# MD_EARN_WNE_P10        597
# GRAD_DEBT_MDN_SUPP    2037
# dtype: int64

# %%
binary_cols = college_n.columns[criteria].tolist()
binary_cols
# Out:
# ['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER']

# %%
college_n2 = college_n.drop(labels=binary_cols, axis='columns')
college_n2.head()
# Out:
#                                      SATVRMID  SATMTMID     UGDS  ...  \
# INSTNM                                                            ...
# Alabama A & M University                424.0     420.0   4206.0  ...
# University of Alabama at Birmingham     570.0     565.0  11383.0  ...
# Amridge University                        NaN       NaN    291.0  ...
# University of Alabama in Huntsville     595.0     590.0   5451.0  ...
# Alabama State University                425.0     430.0   4811.0  ...
#
#                                      UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University              0.1049          30300.0
# University of Alabama at Birmingham   0.2422          39700.0
# Amridge University                    0.8540          40100.0
# University of Alabama in Huntsville   0.2640          45500.0
# Alabama State University              0.1270          26600.0
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                        33888.0
# University of Alabama at Birmingham             21941.5
# Amridge University                              23370.0
# University of Alabama in Huntsville             24097.0
# Alabama State University                        33118.5
#
# [5 rows x 18 columns]

# %%
college_n2.head(20)
# Out:
#                                                  SATVRMID  SATMTMID     UGDS  \
# INSTNM
# Alabama A & M University                            424.0     420.0   4206.0
# University of Alabama at Birmingham                 570.0     565.0  11383.0
# Amridge University                                    NaN       NaN    291.0
# University of Alabama in Huntsville                 595.0     590.0   5451.0
# Alabama State University                            425.0     430.0   4811.0
# The University of Alabama                           555.0     565.0  29851.0
# Central Alabama Community College                     NaN       NaN   1592.0
# Athens State University                               NaN       NaN   2991.0
# Auburn University at Montgomery                     486.0     509.0   4304.0
# Auburn University                                   575.0     588.0  20514.0
# Birmingham Southern College                         560.0     560.0   1180.0
# Chattahoochee Valley Community College                NaN       NaN   1727.0
# Concordia College Alabama                           420.0     400.0    322.0
# South University-Montgomery                           NaN       NaN    522.0
# Enterprise State Community College                    NaN       NaN   1729.0
# James H Faulkner State Community College              NaN       NaN   4286.0
# Faulkner University                                   NaN       NaN   2367.0
# Gadsden State Community College                       NaN       NaN   4917.0
# New Beginning College of Cosmetology                  NaN       NaN    115.0
# George C Wallace State Community College-Dothan       NaN       NaN   4293.0
#
#                                                  ...  UG25ABV  \
# INSTNM                                           ...
# Alabama A & M University                         ...   0.1049
# University of Alabama at Birmingham              ...   0.2422
# Amridge University                               ...   0.8540
# University of Alabama in Huntsville              ...   0.2640
# Alabama State University                         ...   0.1270
# The University of Alabama                        ...   0.0853
# Central Alabama Community College                ...   0.3153
# Athens State University                          ...   0.6410
# Auburn University at Montgomery                  ...   0.2930
# Auburn University                                ...   0.0415
# Birmingham Southern College                      ...   0.0152
# Chattahoochee Valley Community College           ...   0.3876
# Concordia College Alabama                        ...   0.2367
# South University-Montgomery                      ...   0.5726
# Enterprise State Community College               ...   0.3399
# James H Faulkner State Community College         ...   0.2909
# Faulkner University                              ...   0.4589
# Gadsden State Community College                  ...   0.3733
# New Beginning College of Cosmetology             ...   0.3933
# George C Wallace State Community College-Dothan  ...   0.3920
#
#                                                  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                 30300.0
# University of Alabama at Birmingham                      39700.0
# Amridge University                                       40100.0
# University of Alabama in Huntsville                      45500.0
# Alabama State University                                 26600.0
# The University of Alabama                                41900.0
# Central Alabama Community College                        27500.0
# Athens State University                                  39000.0
# Auburn University at Montgomery                          35000.0
# Auburn University                                        45700.0
# Birmingham Southern College                              44200.0
# Chattahoochee Valley Community College                   26100.0
# Concordia College Alabama                                19900.0
# South University-Montgomery                              28800.0
# Enterprise State Community College                       24600.0
# James H Faulkner State Community College                 28700.0
# Faulkner University                                      37200.0
# Gadsden State Community College                          25700.0
# New Beginning College of Cosmetology                         NaN
# George C Wallace State Community College-Dothan          26600.0
#
#                                                  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                    33888.0
# University of Alabama at Birmingham                         21941.5
# Amridge University                                          23370.0
# University of Alabama in Huntsville                         24097.0
# Alabama State University                                    33118.5
# The University of Alabama                                   23750.0
# Central Alabama Community College                           16127.0
# Athens State University                                     18595.0
# Auburn University at Montgomery                             21335.0
# Auburn University                                           21831.0
# Birmingham Southern College                                 27000.0
# Chattahoochee Valley Community College                       9000.0
# Concordia College Alabama                                       NaN
# South University-Montgomery                                 25167.0
# Enterprise State Community College                           8273.0
# James H Faulkner State Community College                    11000.0
# Faulkner University                                         22000.0
# Gadsden State Community College                                 NaN
# New Beginning College of Cosmetology                         5500.0
# George C Wallace State Community College-Dothan                 NaN
#
# [20 rows x 18 columns]

# %%
college_n2.loc['California Institute of Technology']
# Out:
# SATVRMID                765.0000
# SATMTMID                785.0000
# UGDS                    983.0000
# UGDS_WHITE                0.2787
# UGDS_BLACK                0.0153
# UGDS_HISP                 0.1221
# UGDS_ASIAN                0.4385
# UGDS_AIAN                 0.0010
# UGDS_NHPI                 0.0000
# UGDS_2MOR                 0.0570
# UGDS_NRA                  0.0875
# UGDS_UNKN                 0.0000
# PPTUG_EF                  0.0000
# PCTPELL                   0.1126
# PCTFLOAN                  0.2303
# UG25ABV                   0.0082
# MD_EARN_WNE_P10       77800.0000
# GRAD_DEBT_MDN_SUPP    11812.5000
# Name: California Institute of Technology, dtype: float64

# %%
max_cols = college_n2.idxmax() # return index for each column where they have max values
max_cols
# Out:
# SATVRMID                             California Institute of Technology
# SATMTMID                             California Institute of Technology
# UGDS                                      University of Phoenix-Arizona
# UGDS_WHITE                       Mr Leon's School of Hair Design-Moscow
# UGDS_BLACK                           Velvatex College of Beauty Culture
# UGDS_HISP                       Thunderbird School of Global Management
# UGDS_ASIAN                          Cosmopolitan Beauty and Tech School
# UGDS_AIAN                             Haskell Indian Nations University
# UGDS_NHPI                                       Palau Community College
# UGDS_2MOR                                                 LIU Brentwood
# UGDS_NRA               California University of Management and Sciences
# UGDS_UNKN             Le Cordon Bleu College of Culinary Arts-San Fr...
# PPTUG_EF                        Thunderbird School of Global Management
# PCTPELL                                        MTI Business College Inc
# PCTFLOAN                                         ABC Beauty College Inc
# UG25ABV                                  Dongguk University-Los Angeles
# MD_EARN_WNE_P10                            Medical College of Wisconsin
# GRAD_DEBT_MDN_SUPP           Southwest University of Visual Arts-Tucson
# dtype: object

# %%
max_cols
# Out:
# SATVRMID                             California Institute of Technology
# SATMTMID                             California Institute of Technology
# UGDS                                      University of Phoenix-Arizona
# UGDS_WHITE                       Mr Leon's School of Hair Design-Moscow
# UGDS_BLACK                           Velvatex College of Beauty Culture
# UGDS_HISP                       Thunderbird School of Global Management
# UGDS_ASIAN                          Cosmopolitan Beauty and Tech School
# UGDS_AIAN                             Haskell Indian Nations University
# UGDS_NHPI                                       Palau Community College
# UGDS_2MOR                                                 LIU Brentwood
# UGDS_NRA               California University of Management and Sciences
# UGDS_UNKN             Le Cordon Bleu College of Culinary Arts-San Fr...
# PPTUG_EF                        Thunderbird School of Global Management
# PCTPELL                                        MTI Business College Inc
# PCTFLOAN                                         ABC Beauty College Inc
# UG25ABV                                  Dongguk University-Los Angeles
# MD_EARN_WNE_P10                            Medical College of Wisconsin
# GRAD_DEBT_MDN_SUPP           Southwest University of Visual Arts-Tucson
# dtype: object

# %%
max_cols.unique()
# Out:
# array(['California Institute of Technology',
#        'University of Phoenix-Arizona',
#        "Mr Leon's School of Hair Design-Moscow",
#        'Velvatex College of Beauty Culture',
#        'Thunderbird School of Global Management',
#        'Cosmopolitan Beauty and Tech School',
#        'Haskell Indian Nations University', 'Palau Community College',
#        'LIU Brentwood',
#        'California University of Management and Sciences',
#        'Le Cordon Bleu College of Culinary Arts-San Francisco',
#        'MTI Business College Inc', 'ABC Beauty College Inc',
#        'Dongguk University-Los Angeles', 'Medical College of Wisconsin',
#        'Southwest University of Visual Arts-Tucson'], dtype=object)

# %%
unique_max_cols = max_cols.unique() #convert to array
unique_max_cols[:5]
# Out:
# array(['California Institute of Technology',
#        'University of Phoenix-Arizona',
#        "Mr Leon's School of Hair Design-Moscow",
#        'Velvatex College of Beauty Culture',
#        'Thunderbird School of Global Management'], dtype=object)

# %%
college_n2.loc[unique_max_cols].style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col0 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col1 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col2 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row2_col3 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row3_col4 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row4_col5 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row4_col12 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row5_col6 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row6_col7 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row7_col8 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row8_col9 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row9_col10 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row10_col11 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row11_col13 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row11_col14 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row12_col14 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row13_col15 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row14_col16 {
#             background-color:  yellow;
#         }    #T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row15_col17 {
#             background-color:  yellow;
#         }</style><table id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SATVRMID</th>        <th class="col_heading level0 col1" >SATMTMID</th>        <th class="col_heading level0 col2" >UGDS</th>        <th class="col_heading level0 col3" >UGDS_WHITE</th>        <th class="col_heading level0 col4" >UGDS_BLACK</th>        <th class="col_heading level0 col5" >UGDS_HISP</th>        <th class="col_heading level0 col6" >UGDS_ASIAN</th>        <th class="col_heading level0 col7" >UGDS_AIAN</th>        <th class="col_heading level0 col8" >UGDS_NHPI</th>        <th class="col_heading level0 col9" >UGDS_2MOR</th>        <th class="col_heading level0 col10" >UGDS_NRA</th>        <th class="col_heading level0 col11" >UGDS_UNKN</th>        <th class="col_heading level0 col12" >PPTUG_EF</th>        <th class="col_heading level0 col13" >PCTPELL</th>        <th class="col_heading level0 col14" >PCTFLOAN</th>        <th class="col_heading level0 col15" >UG25ABV</th>        <th class="col_heading level0 col16" >MD_EARN_WNE_P10</th>        <th class="col_heading level0 col17" >GRAD_DEBT_MDN_SUPP</th>    </tr>    <tr>        <th class="index_name level0" >INSTNM</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2level0_row0" class="row_heading level0 row0" >California Institute of Technology</th>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col0" class="data row0 col0" >765</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col1" class="data row0 col1" >785</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col2" class="data row0 col2" >983</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col3" class="data row0 col3" >0.2787</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col4" class="data row0 col4" >0.0153</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col5" class="data row0 col5" >0.1221</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col6" class="data row0 col6" >0.4385</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col7" class="data row0 col7" >0.001</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col9" class="data row0 col9" >0.057</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col10" class="data row0 col10" >0.0875</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col13" class="data row0 col13" >0.1126</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col14" class="data row0 col14" >0.2303</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col15" class="data row0 col15" >0.0082</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col16" class="data row0 col16" >77800</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row0_col17" class="data row0 col17" >11812.5</td>
#             </tr>
#             <tr>
#                         <th id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2level0_row1" class="row_heading level0 row1" >University of Phoenix-Arizona</th>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col2" class="data row1 col2" >151558</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col3" class="data row1 col3" >0.3098</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col4" class="data row1 col4" >0.1555</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col5" class="data row1 col5" >0.076</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col6" class="data row1 col6" >0.0082</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col7" class="data row1 col7" >0.0042</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col8" class="data row1 col8" >0.005</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col9" class="data row1 col9" >0.1131</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col10" class="data row1 col10" >0.0131</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col11" class="data row1 col11" >0.3152</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_9aa5_8091d7a966d2row1_col13" class="data row1 col13" >0.6009</td>
#                         <td id="T_9cd9aaa8_18f1_11ea_

# %% [markdown]
# ## There's more...

# %%
college = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/college.csv', index_col='INSTNM')
college_ugds = college.filter(like='UGDS_').head() #default axis is column for dataframe
college_ugds.style.highlight_max(axis='columns')
# Out:
# <style  type="text/css" >
#     #T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col1 {
#             background-color:  yellow;
#         }    #T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col0 {
#             background-color:  yellow;
#         }    #T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col1 {
#             background-color:  yellow;
#         }    #T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col0 {
#             background-color:  yellow;
#         }    #T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col1 {
#             background-color:  yellow;
#         }</style><table id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >UGDS_WHITE</th>        <th class="col_heading level0 col1" >UGDS_BLACK</th>        <th class="col_heading level0 col2" >UGDS_HISP</th>        <th class="col_heading level0 col3" >UGDS_ASIAN</th>        <th class="col_heading level0 col4" >UGDS_AIAN</th>        <th class="col_heading level0 col5" >UGDS_NHPI</th>        <th class="col_heading level0 col6" >UGDS_2MOR</th>        <th class="col_heading level0 col7" >UGDS_NRA</th>        <th class="col_heading level0 col8" >UGDS_UNKN</th>    </tr>    <tr>        <th class="index_name level0" >INSTNM</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2level0_row0" class="row_heading level0 row0" >Alabama A & M University</th>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col0" class="data row0 col0" >0.0333</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col1" class="data row0 col1" >0.9353</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col2" class="data row0 col2" >0.0055</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col3" class="data row0 col3" >0.0019</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col4" class="data row0 col4" >0.0024</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col5" class="data row0 col5" >0.0019</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col7" class="data row0 col7" >0.0059</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row0_col8" class="data row0 col8" >0.0138</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2level0_row1" class="row_heading level0 row1" >University of Alabama at Birmingham</th>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col0" class="data row1 col0" >0.5922</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col1" class="data row1 col1" >0.26</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col2" class="data row1 col2" >0.0283</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col3" class="data row1 col3" >0.0518</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col4" class="data row1 col4" >0.0022</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col5" class="data row1 col5" >0.0007</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col6" class="data row1 col6" >0.0368</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col7" class="data row1 col7" >0.0179</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row1_col8" class="data row1 col8" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2level0_row2" class="row_heading level0 row2" >Amridge University</th>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col0" class="data row2 col0" >0.299</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col1" class="data row2 col1" >0.4192</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col2" class="data row2 col2" >0.0069</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col3" class="data row2 col3" >0.0034</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row2_col8" class="data row2 col8" >0.2715</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2level0_row3" class="row_heading level0 row3" >University of Alabama in Huntsville</th>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col0" class="data row3 col0" >0.6988</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col1" class="data row3 col1" >0.1255</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col2" class="data row3 col2" >0.0382</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col3" class="data row3 col3" >0.0376</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col4" class="data row3 col4" >0.0143</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col5" class="data row3 col5" >0.0002</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col6" class="data row3 col6" >0.0172</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col7" class="data row3 col7" >0.0332</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row3_col8" class="data row3 col8" >0.035</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2level0_row4" class="row_heading level0 row4" >Alabama State University</th>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col0" class="data row4 col0" >0.0158</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col1" class="data row4 col1" >0.9208</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col2" class="data row4 col2" >0.0121</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col3" class="data row4 col3" >0.0019</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col4" class="data row4 col4" >0.001</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col5" class="data row4 col5" >0.0006</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col6" class="data row4 col6" >0.0098</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col7" class="data row4 col7" >0.0243</td>
#                         <td id="T_a7d01234_18f1_11ea_ba5d_8091d7a966d2row4_col8" class="data row4 col8" >0.0137</td>
#             </tr>
#     </tbody></table>

# %%
pd.Timedelta(1, unit='Y')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: M and Y units are deprecated and will be removed in a future version.
#   """Entry point for launching an IPython kernel.
# Timedelta('365 days 05:49:12')

# %% [markdown]
# # Replicating idxmax with method chaining

# %%
college = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/college.csv', index_col='INSTNM')

# %%
college.head(3)
# Out:
#                                            CITY STABBR  HBCU  ...  UG25ABV  \
# INSTNM                                                        ...
# Alabama A & M University                 Normal     AL   1.0  ...   0.1049
# University of Alabama at Birmingham  Birmingham     AL   0.0  ...   0.2422
# Amridge University                   Montgomery     AL   0.0  ...   0.8540
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                       30300               33888
# University of Alabama at Birmingham            39700             21941.5
# Amridge University                             40100               23370
#
# [3 rows x 26 columns]

# %%
cols = ['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']
for col in cols:
    college[col] = pd.to_numeric(college[col], errors='coerce')

# %%
college.head(3)
# Out:
#                                            CITY STABBR  HBCU  ...  UG25ABV  \
# INSTNM                                                        ...
# Alabama A & M University                 Normal     AL   1.0  ...   0.1049
# University of Alabama at Birmingham  Birmingham     AL   0.0  ...   0.2422
# Amridge University                   Montgomery     AL   0.0  ...   0.8540
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
#
# [3 rows x 26 columns]

# %%
college_n = college.select_dtypes(include=[np.number])

# %%
college_n
# Out:
#                                                     HBCU  MENONLY  WOMENONLY  \
# INSTNM
# Alabama A & M University                             1.0      0.0        0.0
# University of Alabama at Birmingham                  0.0      0.0        0.0
# Amridge University                                   0.0      0.0        0.0
# University of Alabama in Huntsville                  0.0      0.0        0.0
# Alabama State University                             1.0      0.0        0.0
# ...                                                  ...      ...        ...
# SAE Institute of Technology  San Francisco           NaN      NaN        NaN
# Rasmussen College - Overland Park                    NaN      NaN        NaN
# National Personal Training Institute of Cleveland    NaN      NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...   NaN      NaN        NaN
# Excel Learning Center-San Antonio South              NaN      NaN        NaN
#
#                                                     ...  UG25ABV  \
# INSTNM                                              ...
# Alabama A & M University                            ...   0.1049
# University of Alabama at Birmingham                 ...   0.2422
# Amridge University                                  ...   0.8540
# University of Alabama in Huntsville                 ...   0.2640
# Alabama State University                            ...   0.1270
# ...                                                 ...      ...
# SAE Institute of Technology  San Francisco          ...      NaN
# Rasmussen College - Overland Park                   ...      NaN
# National Personal Training Institute of Cleveland   ...      NaN
# Bay Area Medical Academy - San Jose Satellite L...  ...      NaN
# Excel Learning Center-San Antonio South             ...      NaN
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                    30300.0
# University of Alabama at Birmingham                         39700.0
# Amridge University                                          40100.0
# University of Alabama in Huntsville                         45500.0
# Alabama State University                                    26600.0
# ...                                                             ...
# SAE Institute of Technology  San Francisco                      NaN
# Rasmussen College - Overland Park                               NaN
# National Personal Training Institute of Cleveland               NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                       33888.0
# University of Alabama at Birmingham                            21941.5
# Amridge University                                             23370.0
# University of Alabama in Huntsville                            24097.0
# Alabama State University                                       33118.5
# ...                                                                ...
# SAE Institute of Technology  San Francisco                      9500.0
# Rasmussen College - Overland Park                              21163.0
# National Personal Training Institute of Cleveland               6333.0
# Bay Area Medical Academy - San Jose Satellite L...                 NaN
# Excel Learning Center-San Antonio South                        12125.0
#
# [7535 rows x 24 columns]

# %%
criteria = college_n.nunique() == 2

# %%
criteria
# Out:
# HBCU                   True
# MENONLY                True
# WOMENONLY              True
# RELAFFIL               True
# SATVRMID              False
# SATMTMID              False
# DISTANCEONLY           True
# UGDS                  False
# UGDS_WHITE            False
# UGDS_BLACK            False
# UGDS_HISP             False
# UGDS_ASIAN            False
# UGDS_AIAN             False
# UGDS_NHPI             False
# UGDS_2MOR             False
# UGDS_NRA              False
# UGDS_UNKN             False
# PPTUG_EF              False
# CURROPER               True
# PCTPELL               False
# PCTFLOAN              False
# UG25ABV               False
# MD_EARN_WNE_P10       False
# GRAD_DEBT_MDN_SUPP    False
# dtype: bool

# %%
binary_cols = college_n.columns[criteria].tolist() #create list of all True columns

# %%
binary_cols
# Out:
# ['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER']

# %%
college_n = college_n.drop(labels=binary_cols, axis='columns')

# %%
college_n
# Out:
#                                                     SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                               424.0     420.0
# University of Alabama at Birmingham                    570.0     565.0
# Amridge University                                       NaN       NaN
# University of Alabama in Huntsville                    595.0     590.0
# Alabama State University                               425.0     430.0
# ...                                                      ...       ...
# SAE Institute of Technology  San Francisco               NaN       NaN
# Rasmussen College - Overland Park                        NaN       NaN
# National Personal Training Institute of Cleveland        NaN       NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN       NaN
# Excel Learning Center-San Antonio South                  NaN       NaN
#
#                                                        UGDS  ...  UG25ABV  \
# INSTNM                                                       ...
# Alabama A & M University                             4206.0  ...   0.1049
# University of Alabama at Birmingham                 11383.0  ...   0.2422
# Amridge University                                    291.0  ...   0.8540
# University of Alabama in Huntsville                  5451.0  ...   0.2640
# Alabama State University                             4811.0  ...   0.1270
# ...                                                     ...  ...      ...
# SAE Institute of Technology  San Francisco              NaN  ...      NaN
# Rasmussen College - Overland Park                       NaN  ...      NaN
# National Personal Training Institute of Cleveland       NaN  ...      NaN
# Bay Area Medical Academy - San Jose Satellite L...      NaN  ...      NaN
# Excel Learning Center-San Antonio South                 NaN  ...      NaN
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                    30300.0
# University of Alabama at Birmingham                         39700.0
# Amridge University                                          40100.0
# University of Alabama in Huntsville                         45500.0
# Alabama State University                                    26600.0
# ...                                                             ...
# SAE Institute of Technology  San Francisco                      NaN
# Rasmussen College - Overland Park                               NaN
# National Personal Training Institute of Cleveland               NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                       33888.0
# University of Alabama at Birmingham                            21941.5
# Amridge University                                             23370.0
# University of Alabama in Huntsville                            24097.0
# Alabama State University                                       33118.5
# ...                                                                ...
# SAE Institute of Technology  San Francisco                      9500.0
# Rasmussen College - Overland Park                              21163.0
# National Personal Training Institute of Cleveland               6333.0
# Bay Area Medical Academy - San Jose Satellite L...                 NaN
# Excel Learning Center-San Antonio South                        12125.0
#
# [7535 rows x 18 columns]

# %%
college_n.max().head(10)
# Out:
# SATVRMID         765.0000
# SATMTMID         785.0000
# UGDS          151558.0000
# UGDS_WHITE         1.0000
# UGDS_BLACK         1.0000
# UGDS_HISP          1.0000
# UGDS_ASIAN         0.9727
# UGDS_AIAN          1.0000
# UGDS_NHPI          0.9983
# UGDS_2MOR          0.5333
# dtype: float64

# %%
college_n[college_n['SATVRMID']==765.000]
# Out:
#                                     SATVRMID  SATMTMID   UGDS  ...  UG25ABV  \
# INSTNM                                                         ...
# California Institute of Technology     765.0     785.0  983.0  ...   0.0082
#
#                                     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# California Institute of Technology          77800.0             11812.5
#
# [1 rows x 18 columns]

# %%
college_n.eq(college_n.max()).head()
# Out:
#                                      SATVRMID  SATMTMID   UGDS  ...  UG25ABV  \
# INSTNM                                                          ...
# Alabama A & M University                False     False  False  ...    False
# University of Alabama at Birmingham     False     False  False  ...    False
# Amridge University                      False     False  False  ...    False
# University of Alabama in Huntsville     False     False  False  ...    False
# Alabama State University                False     False  False  ...    False
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                       False               False
# University of Alabama at Birmingham            False               False
# Amridge University                             False               False
# University of Alabama in Huntsville            False               False
# Alabama State University                       False               False
#
# [5 rows x 18 columns]

# %%
has_row_max = college_n.eq(college_n.max()).any(axis='columns')
has_row_max.head(30)
# Out:
# INSTNM
# Alabama A & M University                               False
# University of Alabama at Birmingham                    False
# Amridge University                                     False
# University of Alabama in Huntsville                    False
# Alabama State University                               False
# The University of Alabama                              False
# Central Alabama Community College                      False
# Athens State University                                False
# Auburn University at Montgomery                        False
# Auburn University                                      False
# Birmingham Southern College                            False
# Chattahoochee Valley Community College                 False
# Concordia College Alabama                              False
# South University-Montgomery                            False
# Enterprise State Community College                     False
# James H Faulkner State Community College               False
# Faulkner University                                    False
# Gadsden State Community College                        False
# New Beginning College of Cosmetology                   False
# George C Wallace State Community College-Dothan        False
# George C Wallace State Community College-Hanceville    False
# George C Wallace State Community College-Selma         False
# Herzing University-Birmingham                          False
# Huntingdon College                                     False
# Heritage Christian University                          False
# J F Drake State Community and Technical College        False
# Jacksonville State University                          False
# Jefferson Davis Community College                      False
# Jefferson State Community College                      False
# John C Calhoun State Community College                 False
# dtype: bool

# %%
college_n.shape
# Out:
# (7535, 18)

# %%
has_row_max.sum()
# Out:
# 401

# %%
pd.options.display.max_rows=6

# %%
college_n.eq(college_n.max()).cumsum().cumsum()
# Out:
#                                                     SATVRMID  SATMTMID  UGDS  \
# INSTNM
# Alabama A & M University                                   0         0     0
# University of Alabama at Birmingham                        0         0     0
# Amridge University                                         0         0     0
# ...                                                      ...       ...   ...
# National Personal Training Institute of Cleveland       7307      7307   417
# Bay Area Medical Academy - San Jose Satellite L...      7308      7308   418
# Excel Learning Center-San Antonio South                 7309      7309   419
#
#                                                     ...  UG25ABV  \
# INSTNM                                              ...
# Alabama A & M University                            ...        0
# University of Alabama at Birmingham                 ...        0
# Amridge University                                  ...        0
# ...                                                 ...      ...
# National Personal Training Institute of Cleveland   ...    36207
# Bay Area Medical Academy - San Jose Satellite L...  ...    36219
# Excel Learning Center-San Antonio South             ...    36231
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                          0
# University of Alabama at Birmingham                               0
# Amridge University                                                0
# ...                                                             ...
# National Personal Training Institute of Cleveland              3447
# Bay Area Medical Academy - San Jose Satellite L...             3448
# Excel Learning Center-San Antonio South                        3449
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                             0
# University of Alabama at Birmingham                                  0
# Amridge University                                                   0
# ...                                                                ...
# National Personal Training Institute of Cleveland                10270
# Bay Area Medical Academy - San Jose Satellite L...               10272
# Excel Learning Center-San Antonio South                          10274
#
# [7535 rows x 18 columns]

# %%
has_row_max2 = college_n.eq(college_n.max())\
                        .cumsum()\
                        .cumsum()\
                        .eq(1)\
                        .any(axis='columns')
has_row_max2.head()
# Out:
# INSTNM
# Alabama A & M University               False
# University of Alabama at Birmingham    False
# Amridge University                     False
# University of Alabama in Huntsville    False
# Alabama State University               False
# dtype: bool

# %%
has_row_max2.sum()
# Out:
# 16

# %%
idxmax_cols = has_row_max2[has_row_max2].index
idxmax_cols
# Out:
# Index(['Thunderbird School of Global Management',
#        'Southwest University of Visual Arts-Tucson', 'ABC Beauty College Inc',
#        'Velvatex College of Beauty Culture',
#        'California Institute of Technology',
#        'Le Cordon Bleu College of Culinary Arts-San Francisco',
#        'MTI Business College Inc', 'Dongguk University-Los Angeles',
#        'Mr Leon's School of Hair Design-Moscow',
#        'Haskell Indian Nations University', 'LIU Brentwood',
#        'Medical College of Wisconsin', 'Palau Community College',
#        'California University of Management and Sciences',
#        'Cosmopolitan Beauty and Tech School', 'University of Phoenix-Arizona'],
#       dtype='object', name='INSTNM')

# %%
set(college_n.idxmax().unique()) == set(idxmax_cols)
# Out:
# True

# %% [markdown]
# ## There's more...

# %%
# %timeit college_n.idxmax().values
# Out:
# 3.21 ms ± 248 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit college_n.eq(college_n.max())\
                              .cumsum()\
                              .cumsum()\
                              .eq(1)\
                              .any(axis='columns')\
                              [lambda x: x].index
# Out:
# 25.5 ms ± 794 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Finding the most common maximum

# %%
pd.options.display.max_rows= 40

# %%
college = pd.read_csv('https://raw.githubusercontent.com/AnkitNigam1985/Data-Science/master/Pandas/college.csv', index_col='INSTNM')
college_ugds = college.filter(like='UGDS_')
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  ...  \
# INSTNM                                                                  ...
# Alabama A & M University                 0.0333      0.9353     0.0055  ...
# University of Alabama at Birmingham      0.5922      0.2600     0.0283  ...
# Amridge University                       0.2990      0.4192     0.0069  ...
# University of Alabama in Huntsville      0.6988      0.1255     0.0382  ...
# Alabama State University                 0.0158      0.9208     0.0121  ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138
# University of Alabama at Birmingham     0.0368    0.0179     0.0100
# Amridge University                      0.0000    0.0000     0.2715
# University of Alabama in Huntsville     0.0172    0.0332     0.0350
# Alabama State University                0.0098    0.0243     0.0137
#
# [5 rows x 9 columns]

# %%
highest_percentage_race = college_ugds.idxmax(axis='columns') # max column for each row
highest_percentage_race.head()
# Out:
# INSTNM
# Alabama A & M University               UGDS_BLACK
# University of Alabama at Birmingham    UGDS_WHITE
# Amridge University                     UGDS_BLACK
# University of Alabama in Huntsville    UGDS_WHITE
# Alabama State University               UGDS_BLACK
# dtype: object

# %%
highest_percentage_race.value_counts(normalize=True)
# Out:
# UGDS_WHITE    0.670352
# UGDS_BLACK    0.151586
# UGDS_HISP     0.129473
#                 ...
# UGDS_NRA      0.004073
# UGDS_NHPI     0.001746
# UGDS_2MOR     0.001164
# Length: 9, dtype: float64

# %% [markdown]
# # There's more...

# %%
college_black = college_ugds[highest_percentage_race == 'UGDS_BLACK']
college_black = college_black.drop('UGDS_BLACK', axis='columns')
college_black.idxmax(axis='columns').value_counts(normalize=True)
# Out:
# UGDS_WHITE    0.661228
# UGDS_HISP     0.230326
# UGDS_UNKN     0.071977
#                 ...
# UGDS_2MOR     0.006718
# UGDS_NHPI     0.000960
# UGDS_AIAN     0.000960
# Length: 8, dtype: float64
